# %% [markdown]
# Generación de Datos Aleatorios

# %%
import numpy as np
# Generar datos aleatorios con dos caracteristicas para la demostración

np.random.seed(0)
X = np.random.rand(100, 2)

print("Datos generados aleatoriamente:")
print(X[:5])
# Out:
# Datos generados aleatoriamente:
# [[0.5488135  0.71518937]
#  [0.60276338 0.54488318]
#  [0.4236548  0.64589411]
#  [0.43758721 0.891773  ]
#  [0.96366276 0.38344152]]

# %% [markdown]
# Cálculo de la Distancia Euclidiana

# %%
from scipy.spatial.distance import euclidean

# Calcular la distancia euclidiana entre dos puntos
punto1 = X[1]
punto2 = X[4]
distancia = euclidean(punto1, punto2)

print(f"Distancia euclidiana entre los puntos:", distancia)
# Out:
# Distancia euclidiana entre los puntos: 0.3953628417186543

# %% [markdown]
# Implementación de K-Means

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Generar datos aleatorios para clustering
X = np.random.rand(100, 2)

# Inicializar y ajustar el modelo K-Means
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

# Visualizar los clusters
plt.scatter(X[:, 0], X[:, 1], c=kmeans.labels_, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X', s=200)
plt.title('Clustering con K-Means')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()

# %% [markdown]
# Aplicación de Clustering en un Conjunto de Datos Real

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data
y = iris.target

# Normalizar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA para reducir la dimensionalidad
kmeans = KMeans(n_clusters=3)
kmeans.fit(X_scaled)

# Visualizar los clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_, cmap='viridis')
plt.title('Clustering con K-Means en el Conjunto de Datos Iris')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.show()
