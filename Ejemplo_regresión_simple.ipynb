# %% [markdown]
# <a href="https://colab.research.google.com/github/erzdwin/Talento_Tech_IA/blob/main/Ejemplo_regresi%C3%B3n_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
value_x= [1, 2, 2, 3, 4, 4, 5, 6]
value_y= [2, 3, 4, 4, 4, 6, 5, 7]

data_dict = {"x":value_x,
             "y":value_y}

df_regression= pd.DataFrame(data_dict)
df_regression
# Out:
#    x  y
# 0  1  2
# 1  2  3
# 2  2  4
# 3  3  4
# 4  4  4
# 5  4  6
# 6  5  5
# 7  6  7

# %%
df_regression['xy'] = df_regression['x'] * df_regression['y']
df_regression
# Out:
#    x  y  xy
# 0  1  2   2
# 1  2  3   6
# 2  2  4   8
# 3  3  4  12
# 4  4  4  16
# 5  4  6  24
# 6  5  5  25
# 7  6  7  42

# %%
df_regression['x^2'] = df_regression['x'] ** 2
df_regression
# Out:
#    x  y  xy  x^2
# 0  1  2   2    1
# 1  2  3   6    4
# 2  2  4   8    4
# 3  3  4  12    9
# 4  4  4  16   16
# 5  4  6  24   16
# 6  5  5  25   25
# 7  6  7  42   36

# %%
df_regression.loc['Total'] = df_regression.sum()
df_regression
# Out:
#         x   y   xy  x^2
# 0       1   2    2    1
# 1       2   3    6    4
# 2       2   4    8    4
# 3       3   4   12    9
# 4       4   4   16   16
# 5       4   6   24   16
# 6       5   5   25   25
# 7       6   7   42   36
# Total  27  35  135  111

# %%
n = len(df)
m = ((n * df['xy'].sum()) - (df['x'].sum() * df['y'].sum())) / ((n * df['x^2'].sum()) - (df['x'].sum()**2))
m = round(m, 3)
m
# Out:
# 0.849

# %%
b = df_regression['y'].mean() - (m * df_regression['x'].mean())
b = round(b, 4)
b
# Out:
# 1.5096

# %%
x = np.array(df_regression['x'])
y = m * x + b

plt.plot(df_regression['x'], df_regression['y'], 'o', color='red') # puntos azules
plt.plot(x, y, color='blue') # línea roja
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gráfico de df_regression con línea de regresión')
plt.show()

# %%
sns.regplot(x='x', y='y', data=df_regression, scatter_kws={"color": "red"}, line_kws={"color": "blue"}).set(title='Regression y= m(x)+b ')
plt.show()

# %%
sum((df_regression['y'] - (m * df_regression['x'] + b))**2)
# Out:
# 3.5471698800000007

# %% [markdown]
# Respuesta (d)
